# %%
import pandas as pd

data = {
    '流量来源': ['一级-A', '一级-B', '一级-C', '一级-D', '一级-E', '一级-F', '一级-G', '一级-H', 
              '一级-I', '一级-J', '一级-K', '一级-L', '一级-M', '二级-A', '二级-B', '二级-C', '三级-A'],
    '来源明细': ['一级-A', '一级-B', '一级-C', '一级-D', '一级-E', '一级-F', '一级-G', '一级-H', 
              '一级-I', '一级-J', '一级-K', '一级-L', '一级-M', '二级-A', '二级-B', '二级-C', '三级-A'],
    '访客数': [35188, 28467, 13747, 5183, 4361, 4063, 2122, 2041, 1991, 1981, 1958, 1780, 1447, 
              39048, 3316, 2043, 23140],
    '支付转化率': [0.099, 0.112, 0.025, 0.024, 0.043, 0.115, 0.102, 0.070, 0.165, 0.057, 0.147, 
                0.131, 0.010, 0.116, 0.070, 0.050, 0.096],
    '客单价': [854.30, 799.93, 540.08, 737.15, 191.73, 765.09, 786.45, 644.07, 104.57, 575.93, 
              185.03, 598.87, 480.07, 591.91, 566.28, 441.91, 983.75]
}

df = pd.DataFrame(data=data)

print(df.head)
# Out:
# <bound method NDFrame.head of     流量来源  来源明细    访客数  支付转化率     客单价
# 0   一级-A  一级-A  35188  0.099  854.30
# 1   一级-B  一级-B  28467  0.112  799.93
# 2   一级-C  一级-C  13747  0.025  540.08
# 3   一级-D  一级-D   5183  0.024  737.15
# 4   一级-E  一级-E   4361  0.043  191.73
# 5   一级-F  一级-F   4063  0.115  765.09
# 6   一级-G  一级-G   2122  0.102  786.45
# 7   一级-H  一级-H   2041  0.070  644.07
# 8   一级-I  一级-I   1991  0.165  104.57
# 9   一级-J  一级-J   1981  0.057  575.93
# 10  一级-K  一级-K   1958  0.147  185.03
# 11  一级-L  一级-L   1780  0.131  598.87
# 12  一级-M  一级-M   1447  0.010  480.07
# 13  二级-A  二级-A  39048  0.116  591.91
# 14  二级-B  二级-B   3316  0.070  566.28
# 15  二级-C  二级-C   2043  0.050  441.91
# 16  三级-A  三级-A  23140  0.096  983.75>

# %%
# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35]}
df = pd.DataFrame(data)

# %%
# 下一个 Cell
print(df.describe())
print(df.info())
